# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15282, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 15282 (delta 17), reused 26 (delta 7), pack-reused 15236
# Receiving objects: 100% (15282/15282), 14.23 MiB | 18.38 MiB/s, done.
# Resolving deltas: 100% (10471/10471), done.

# %%
# %cd yolov5
# %pip install -r requirements.txt
# Out:
# /content/yolov5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 15.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 79.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 10.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 57.4.0
#     Uninstalling setuptools-57.4.0:
#       Successfully uninstalled setuptools-57.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.9.0 requires jedi>=0.10, which is not installed.
# cvxpy 1.2.3 requires setuptools<=64.0.2, but you have setuptools 67.4.0 which is incompatible.
# ...

# %%
from PIL import Image
from IPython.display import HTML
from base64 import b64encode

# %%
# before transfer learning

# white balloon image
# !python detect.py --source white-balloon-img.jpeg
# hot air balloons image
# !python detect.py --source hot-air-balloons-img.jpeg

# white balloon video
# !python detect.py --source white-balloon-vid.mov
# hot air balloon video
# !python detect.py --source hot-air-balloons-vid.mov
# Out:
# detect: weights=yolov5s.pt, source=white-balloon-img.jpeg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-115-g5ca8e82 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
#
# ...
# 100% 14.1M/14.1M [00:03<00:00, 3.92MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/1 /content/yolov5/white-balloon-img.jpeg: 448x640 1 frisbee, 1 sports ball, 15.7ms
# Speed: 0.6ms pre-process, 15.7ms inference, 30.2ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp
# ...

# %%
white_balloon_img = Image.open('runs/detect/exp/white-balloon-img.jpeg')
hot_air_balloon_img = Image.open('runs/detect/exp2/hot-air-balloons-img.jpeg')

white_balloon_img.show()
hot_air_balloon_img.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# after transfer learning

# white balloon image
# !python detect.py --weights best.pt --source white-balloon-img.jpeg
# hot air balloons image
# !python detect.py --weights best.pt --source hot-air-balloons-img.jpeg

# white balloon video
# !python detect.py --weights best.pt --source white-balloon-vid.mov
# hot air balloon video
# !python detect.py --weights best.pt --source hot-air-balloons-vid.mov
# Out:
# detect: weights=['best.pt'], source=white-balloon-img.jpeg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-115-g5ca8e82 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 206 layers, 12312052 parameters, 0 gradients, 16.1 GFLOPs
# image 1/1 /content/yolov5/white-balloon-img.jpeg: 448x640 1 balloons, 20.7ms
# Speed: 0.5ms pre-process, 20.7ms inference, 1.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp5
# ...

# %%
white_balloon_img2 = Image.open('runs/detect/exp5/white-balloon-img.jpeg')
hot_air_balloon_img2 = Image.open('runs/detect/exp6/hot-air-balloons-img.jpeg')

white_balloon_img2.show()
hot_air_balloon_img2.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
